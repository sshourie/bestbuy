# %% [markdown]
# # Best Buy Project Notebook
#
# ## Data Import

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('best_buy_raw_data.csv')

# %%
df.head(5)
# Out:
#    Encoded_SKU_ID SALES_DATE      SUBCLASS_NAME           CLASS_NAME  \
# 0               1    9/28/17  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 1               2   11/24/17   CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 2               3   11/28/19           SO PARTS   MOBILE ACCESSORIES
# 3               4    4/21/21  SO RANGEHOODS REG  KITCHEN VENTILATION
# 4               1   10/27/18  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
#
#                ML_NAME          CATEGORY_NAME  RETAIL_PRICE PROMO_PRICE  \
# 0  ML - DI Accessories   VP - Digital Imaging         89.99           ?
# 1  ML - DI Accessories   VP - Digital Imaging         39.99           ?
# 2   ML - Connected Car   VP - Electrify & Car         49.99           ?
# 3         ML - Kitchen  VP - Major Appliances        549.99           ?
# 4  ML - DI Accessories   VP - Digital Imaging         89.99           ?
#
#   COMPETITOR_PRICE      Inventory  DAILY_UNITS
# 0                ?  Fully-Stocked            1
# 1                ?  Fully-Stocked           18
# 2            46.98    Constrained            7
# 3           498.00  Fully-Stocked            6
# 4                ?  Fully-Stocked            7

# %%
df.iloc[9]
# Out:
# Encoded_SKU_ID                                        9
# SALES_DATE                                       7/9/21
# SUBCLASS_NAME                      DIGITAL VIDEO
# CLASS_NAME                           DIGITAL CAMCORDERS
# ML_NAME             ML - P&S and Action Cams and Drones
# CATEGORY_NAME                      VP - Digital Imaging
# RETAIL_PRICE                                     599.99
# PROMO_PRICE                                           ?
# COMPETITOR_PRICE                                 597.99
# Inventory                                 Fully-Stocked
# DAILY_UNITS                                          15
# Name: 9, dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
# Remove trailing spaces
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# Replace "?" with "N/A"
df = df.replace('?', np.nan)

# Convert date format
df['SALES_DATE'] = pd.to_datetime(df['SALES_DATE'], format='%m/%d/%y').dt.strftime('%d%m%Y')

# Remove ML and VP in categories for improved readability
df['ML_NAME'] = df['ML_NAME'].str.slice(4)
df['CATEGORY_NAME'] = df['CATEGORY_NAME'].str.slice(4)

# %%
df.head(20)
# Out:
#     Encoded_SKU_ID SALES_DATE       SUBCLASS_NAME           CLASS_NAME  \
# 0                1   28092017   MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 1                2   24112017    CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 2                3   28112019            SO PARTS   MOBILE ACCESSORIES
# 3                4   21042021   SO RANGEHOODS REG  KITCHEN VENTILATION
# 4                1   27102018   MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 5                5   18122018  SO CAR ACCESSORIES   MOBILE ACCESSORIES
# 6                6   23052019       SUB ENCLOSURE   MOBILE ACCESSORIES
# 7                7   13042018  SO CAR ACCESSORIES   MOBILE ACCESSORIES
# 8                8   04032022     ACTION CAM ACCY  DIGITAL CAMERA ACCY
# 9                9   09072021       DIGITAL VIDEO   DIGITAL CAMCORDERS
# 10              10   22052022        DECK HARNESS   MOBILE ACCESSORIES
# 11              11   14112019           MISC ACCY   MOBILE ACCESSORIES
# 12              12   08112018   MIRRORLESS LENSES               LENSES
# 13              13   09012021  IN DASH NAVIGATION           CAR STEREO
# 14              14   18092019            AMP ACCY   MOBILE ACCESSORIES
# 15              15   26052022           MISC ACCY   MOBILE ACCESSORIES
# 16              16   03022022           DASH KITS   MOBILE ACCESSORIES
# 17              18   28102020       SUB ENCLOSURE   MOBILE ACCESSORIES
# 18              19   14032021     SPEAKER HARNESS   MOBILE ACCESSORIES
# 19              20   16112021      CC MICROPHONES  DIGITAL CAMERA ACCY
#
#                             ML_NAME      CATEGORY_NAME  RETAIL_PRICE  \
# 0                    DI Accessories    Digital Imaging         89.99
# 1                    DI Accessories    Digital Imaging         39.99
# 2                     Connected Car    Electrify & Car         49.99
# 3                           Kitchen   Major Appliances        549.99
# 4                    DI Accessories    Digital Imaging         89.99
# 5                     Connected Car    Electrify & Car         16.99
# 6                     Connected Car    Electrify & Car         59.99
# 7                     Connected Car    Electrify & Car         16.99
# 8                    DI Accessories    Digital Imaging         19.99
# 9    P&S and Action Cams and Drones    Digital Imaging        599.99
# 10                    Connected Car    Electrify & Car         79.99
# 11                    Connected Car    Electrify & Car         16.99
# 12               ILC Cameras/Lenses    Digital Imaging        999.99
# 13                    Connected Car    Electrify & Car        799.99
# 14                    Connected Car    Electrify & Car         16.99
# 15                    Connected Car    Electrify & Car         19.99
# 16                    Connected Car    Electrify & Car         10.99
# 17                    Connected Car    Electrify & Car         79.99
# 18                    Connected Car    Electrify & Car         13.99
# 19                   DI Accessories    Digital Imaging         25.99
#
#    PROMO_PRICE COMPETITOR_PRICE      Inventory  DAILY_UNITS
# 0          NaN              NaN  Fully-Stocked            1
# 1          NaN              NaN  Fully-Stocked           18
# 2          NaN            46.98    Constrained            7
# 3          NaN           498.00  Fully-Stocked            6
# 4          NaN              NaN  Fully-Stocked            7
# 5          NaN              NaN  Fully-Stocked            5
# 6          NaN              NaN  Fully-Stocked            7
# 7          NaN              NaN  Fully-Stocked            4
# 8          NaN            13.32  Fully-Stocked            5
# 9          NaN           597.99  Fully-Stocked           15
# 10         NaN              NaN  Fully-Stocked            2
# 11         NaN              NaN  Fully-Stocked            4
# 12         NaN              NaN  Fully-Stocked            2
# 13         NaN              NaN  Fully-Stocked            3
# 14         NaN              NaN  Fully-Stocked            6
# 15         NaN              NaN  Fully-Stocked            0
# 16         NaN             7.94  Fully-Stocked            2
# 17         NaN              NaN  Fully-Stocked           10
# 18         NaN             8.19  Fully-Stocked            5
# 19         NaN            25.00  Fully-Stocked            5

# %% [markdown]
# ## Data Exploration

# %%
# % of entries with NaN competitor price
NaN_comp_price = df['COMPETITOR_PRICE'].isnull().sum() / (df['COMPETITOR_PRICE'].isnull().sum() + df['COMPETITOR_PRICE'].count())
print("The competitor price is not know for",round(NaN_comp_price*100,1),"percent of the entries.")

# % of entries on promotion
promo_price = df['PROMO_PRICE'].count() / (df['PROMO_PRICE'].isnull().sum() + df['PROMO_PRICE'].count())
print(round(promo_price*100,1),"percent of the entries are on promotion.")

# % of entries with negative daily units
negative_daily_units = (df['DAILY_UNITS'] < 0).sum() / ((df['DAILY_UNITS'] < 0).sum() + df['DAILY_UNITS'].count())
print(round(negative_daily_units*100,1),"percent of the entries have negative daily units.")

# % of entries with zero daily units
zero_daily_units = (df['DAILY_UNITS'] == 0).sum() / ((df['DAILY_UNITS'] == 0).sum() + df['DAILY_UNITS'].count())
print(round(zero_daily_units*100,1),"percent of the entries have zero daily units.")
# Out:
# The competitor price is not know for 63.2 percent of the entries.
# 17.3 percent of the entries are on promotion.
# 0.1 percent of the entries have negative daily units.
# 14.8 percent of the entries have zero daily units.
